# %%
from __future__ import absolute_import, division, print_function

from os import listdir
import xmltodict
import pandas
from StringIO import StringIO
# %matplotlib inline
from tqdm import tqdm
import math
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from datetime import date
from praelexis_file_system_provider.data_access_layer import AzureBlobStorageDataAccessLayer
import PyPDF2
import subprocess
import shutil
import os

import pytesseract
from PIL import Image

# %% [markdown]
# ### Connect to blob storage

# %%
blob_dal = AzureBlobStorageDataAccessLayer('devcapitecdata', 'Gt5z0EAAAm5ZETk//WBnRiQUZ9FDB/BmLmbx5ZPRtDwh6vxTDAB/XzLlM+m/epfnDYcZ8JDfMEGg1p9tBW0iFQ==', 'bank-statements', home_directory='drop/Documentum_line_files')

blob_dal.connect()
files = blob_dal.list(path='CI')

print ("Number of files: ", len(files))
# Out:
# Number of files:  8000

# %%
print(files[500].name)
print(files[501].name)
# Out:
# 0f427a33-cbed-4673-a5d0-79dce1b8d45b.pdf
# 0f427a33-cbed-4673-a5d0-79dce1b8d45b_POCSTATEMENTSSTD_Capitec__19122017_022834_1154.xml

# %% [markdown]
# ### Download random pdfs and their xml files

# %%
folderLoc = "./TestRandomExamples100/"

# %%
import random
random.seed(1000)
numToTest = 3

for i in tqdm(range(numToTest)):
    randNum = int(len(files)/2.0*random.random())*2-10 
    
    while(files[randNum].name[-3:]!="pdf"):
        randNum-=1

    pdfName = files[randNum].directory + files[randNum].name
    
    matchString = files[randNum].name[:-4]
    #print(matchString)
    if matchString in files[randNum-1].name:
        #print(files[randNum].name," ",files[randNum-1].name)
        xmlName = files[randNum-1].directory + files[randNum-1].name
    else:
        #print ("Else")
        #print(files[randNum].name," ",files[randNum+1].name)
        xmlName = files[randNum+1].directory + files[randNum+1].name
    #print ("Downloading: ", pdfName , " and ", xmlName)
        
    stream = StringIO()
    blob_dal.get(pdfName, stream)
    with open (folderLoc+"Example"+str(i+1)+".pdf", 'w') as tmp:
      stream.seek (0)
      shutil.copyfileobj (stream, tmp)
    
    stream = StringIO()
    blob_dal.get(xmlName, stream)
    with open (folderLoc+"Example"+str(i+1)+".xml", 'w') as tmp:
      stream.seek (0)
      shutil.copyfileobj (stream, tmp)
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  6.72it/s]

# %% [markdown]
# ### Convert and test document 1 document

# %% [markdown]
# Command to generate boxes from tesseract
#
# command = 'tesseract ./TestRandomExamples/testText.jpg ./TestRandomExamples/testText  batch.nochop makebox'

# %%
import commands
import time
import glob

exampleNumber = 2

# %env TESSDATA_PREFIX=/leptonica/tesseract/tessdata

pdfNames = glob.glob(folderLoc+"*.pdf")

fileName = pdfNames[exampleNumber-1]

start = time.time()
s=commands.getstatusoutput("convert -density 300 -units pixelsperinch "+str(fileName)+" -quality 100 "+str(fileName[:-4])+".tif")
print(s)
print("It took ",round(time.time()-start,2)," seconds to convert the pdf.")

start = time.time()
command = "tesseract "+str(fileName[:-4])+".tif "+str(fileName[:-4])+ " -l eng bazaar"
print("Command: ", command)
s=commands.getstatusoutput(command)
print(s)
print("It took ",round(time.time()-start), " to run tesseract on the tif file.")

s=commands.getstatusoutput("convert -density 300 -units pixelsperinch "+str(fileName)+" -quality 100 "+str(fileName[:-4])+".tif")
print(s)
print("It took ",round(time.time()-start,2)," seconds to convert the pdf.")
tifLoc = str(fileName[:-4])+".tif"
print("Deleting the tif file.")
s=commands.getstatusoutput("rm " + tifLoc)
print("Tif deleted. Please check.")

print("Done")
# Out:
# env: TESSDATA_PREFIX=/leptonica/tesseract/tessdata
# (0, '')
# It took  14.72  seconds to convert the pdf.
# Command:  tesseract ./TestRandomExamples/Example2.tif ./TestRandomExamples/Example2 -l eng bazaar
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4e127705fef6> in <module>()
#      19 command = "tesseract "+str(fileName[:-4])+".tif "+str(fileName[:-4])+ " -l eng bazaar"
#      20 print("Command: ", command)
# ---> 21 s=commands.getstatusoutput(command)
#      22 print(s)
#      23 print("It took ",round(time.time()-start), " to run tesseract on the tif file.")
#
# /opt/conda/lib/python2.7/commands.pyc in getstatusoutput(cmd)
#      58     import os
#      59     pipe = os.popen('{ ' + cmd + '; } 2>&1', 'r')
# ---> 60     text = pipe.read()
#      61     sts = pipe.close()
#      62     if sts is None: sts = 0
#
# KeyboardInterrupt:

# %% [markdown]
# ### Convert and process all pdfs

# %% [markdown]
# The pdfs are first converted to tif files. The tif files are then sent through Tesseract. A text file is then generated for each pdf image with the estimated text found using Tesseract.

# %%
#import commands
#s=commands.getstatusoutput("tesseract ./TestRandomExamples/Example1.tif ./TestRandomExamples/Example1 -l eng")
#print(s)

# %%
import commands
import time
import glob

# %env TESSDATA_PREFIX=/leptonica/tesseract/tessdata

pdfNames = glob.glob(folderLoc+"*.pdf")

print("Number of pdfs found: ",len(pdfNames))

for i in tqdm(range(len(pdfNames))):
    start = time.time()
    tifLoc = str(pdfNames[i][:-4])+".tif"
    s=commands.getstatusoutput("convert -density 300 -units pixelsperinch "+str(pdfNames[i])+" -quality 100 "+tifLoc)
    print(s)
    print("It took ",round(time.time()-start,2)," seconds to convert the pdf.")

    start = time.time()
    command = "tesseract " + tifLoc + " "+str(pdfNames[i][:-4])+" -l eng"
    print("Command: ", command)
    s=commands.getstatusoutput(command)
    print(s)
    print("It took ",round(time.time()-start), " to run tesseract on the tif file.")
    
    print("Deleting the tif file.")
    s=commands.getstatusoutput("rm " + tifLoc)
    print("Tif deleted. Please check.")
    exit(0)

print("Done")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# env: TESSDATA_PREFIX=/leptonica/tesseract/tessdata
# Number of pdfs found:  3
# (0, '')
# It took  6.8  seconds to convert the pdf.
# Command:  tesseract ./TestRandomExamples/Example1.tif ./TestRandomExamples/Example1 -l eng
# (0, 'Tesseract Open Source OCR Engine v4.00.00alpha with Leptonica\nPage 1\nPage 2\nPage 3\nPage 4')
# It took  49.0  to run tesseract on the tif file.
# Deleting the tif file.
#  33%|███▎      | 1/3 [00:55<01:51, 55.64s/it]
# Tif deleted. Please check.
# (0, '')
# It took  17.22  seconds to convert the pdf.
# Command:  tesseract ./TestRandomExamples/Example2.tif ./TestRandomExamples/Example2 -l eng
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c71ee8f56baa> in <module>()
#      19     command = "tesseract " + tifLoc + " "+str(pdfNames[i][:-4])+" -l eng"
#      20     print("Command: ", command)
# ---> 21     s=commands.getstatusoutput(command)
#      22     print(s)
#      23     print("It took ",round(time.time()-start), " to run tesseract on the tif file.")
#
# /opt/conda/lib/python2.7/commands.pyc in getstatusoutput(cmd)
#      58     import os
#      59     pipe = os.popen('{ ' + cmd + '; } 2>&1', 'r')
# ---> 60     text = pipe.read()
#      61     sts = pipe.close()
#      62     if sts is None: sts = 0
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test amount value errors

# %%
def getValues(fileName):
    f = open(txtNames[i],'r')
    values = []
    line = f.readline()
    while line:

        amountLen = 0
        valueLine = []
        for index,char in enumerate(line):
            
            if amountLen>0:
                if char == '0' or char == '1' or char == '2' or char == '3' or char == '4' or char == '5'or \
                char == '6' or char == '7' or char == '8' or char == '9' or char == ' ' or char == ',' or \
                char == '.' or char == '-' or char == '+':
                    amountLen+=1
                else:
                    if amountLen>1 and line[index-amountLen:index] != "R ":
                        amount = str(line[index-amountLen:index])
                        amount = amount.replace("R", "")
                        amount = amount.replace(",", "")
                        amount = amount.replace(" ", "")
                        amount = amount.replace(".", "")
                        valueLine.append(amount)
                        #print(amount)
                        
                        if len(valueLine)==2:
                            break
                        
                    amountLen = 0
                    
            if char == 'R' and amountLen==0 and (len(valueLine)>0 or line[index-1] == ' '):
                amountLen = 1
        if len(valueLine)>0:
            values.append(valueLine)
        line = f.readline()
    return values
    
def getResult(values):
    possibleAlt = 0.0
    right = 0.0
    total = 0
    skip = 0
    for base in range(1,len(values)):
        i = base# + skip
        try:
            #print(values[i])
            if len(values[i])==2:
                if round(float(values[i][1])-float(values[i][0]),2) == round(float(values[i-1][len(values[i-1])-1]),2):
                    right+=1
                else:
                    skip += 1
                    #print("Wrong. Ans: ", float(values[i][1])," minus ",float(values[i][0])," must equal ",float(values[i-1][len(values[i-1])-1]), ". But true subtraction: ",round(float(values[i][1])-float(values[i][0]),2))
                total += 1
        except:
            #print("Not a number.")
            total +=1
    
    return round(right/total,2) if total>0 else 0.0,total

# %%
import glob
txtNames = glob.glob(folderLoc+"*.txt")
print("Number of textfiles found: ",len(txtNames))
result = np.zeros(len(txtNames))
for i in tqdm(range(len(txtNames))):
    print("File number: ",str(i+1))
    print("File name: ",txtNames[i])
    
    values = getValues(txtNames[i])
    
    res,total = getResult(values)
    result[i] = res
    print("Number of values tested: ",total)
    print("Accuracy: ", res," out of 1.\n")
# Out:
#  37%|███▋      | 37/100 [00:00<00:00, 363.95it/s]
# Number of textfiles found:  100
# File number:  1
# File name:  ./TestRandomExamples100/Example3.txt
# Number of values tested:  153
# Accuracy:  0.73  out of 1.
#
# File number:  2
# File name:  ./TestRandomExamples100/Example2.txt
# Number of values tested:  50
# Accuracy:  0.2  out of 1.
#
# File number:  3
# File name:  ./TestRandomExamples100/Example4.txt
# Number of values tested:  60
# Accuracy:  0.4  out of 1.
#
# File number:  4
# File name:  ./TestRandomExamples100/Example1.txt
# Number of values tested:  44
# Accuracy:  0.25  out of 1.
#
# File number:  5
# File name:  ./TestRandomExamples100/Example5.txt
# Number of values tested:  102
# Accuracy:  0.73  out of 1.
#
# File number:  6
# File name:  ./TestRandomExamples100/Example6.txt
# Number of values tested:  113
# Accuracy:  0.5  out of 1.
#
# File number:  7
# File name:  ./TestRandomExamples100/Example7.txt
# Number of values tested:  19
# Accuracy:  1.0  out of 1.
#
# File number:  8
# File name:  ./TestRandomExamples100/Example8.txt
# Number of values tested:  37
# Accuracy:  0.92  out of 1.
#
# File number:  9
# File name:  ./TestRandomExamples100/Example9.txt
# Number of values tested:  28
# Accuracy:  0.71  out of 1.
#
# File number:  10
# File name:  ./TestRandomExamples100/Example34.txt
# Number of values tested:  179
# Accuracy:  0.75  out of 1.
#
# File number:  11
# File name:  ./TestRandomExamples100/Example10.txt
# Number of values tested:  77
# Accuracy:  0.21  out of 1.
#
# File number:  12
# File name:  ./TestRandomExamples100/Example33.txt
# Number of values tested:  154
# Accuracy:  0.77  out of 1.
#
# File number:  13
# File name:  ./TestRandomExamples100/Example11.txt
# Number of values tested:  78
# Accuracy:  0.74  out of 1.
#
# File number:  14
# File name:  ./TestRandomExamples100/Example35.txt
# Number of values tested:  21
# Accuracy:  0.57  out of 1.
#
# File number:  15
# File name:  ./TestRandomExamples100/Example12.txt
# Number of values tested:  68
# Accuracy:  0.87  out of 1.
#
# File number:  16
# File name:  ./TestRandomExamples100/Example36.txt
# Number of values tested:  57
# Accuracy:  0.96  out of 1.
#
# File number:  17
# File name:  ./TestRandomExamples100/Example13.txt
# Number of values tested:  100
# Accuracy:  0.84  out of 1.
#
# File number:  18
# File name:  ./TestRandomExamples100/Example37.txt
# Number of values tested:  89
# Accuracy:  0.74  out of 1.
#
# File number:  19
# File name:  ./TestRandomExamples100/Example14.txt
# Number of values tested:  43
# Accuracy:  0.05  out of 1.
#
# File number:  20
# File name:  ./TestRandomExamples100/Example38.txt
# Number of values tested:  63
# Accuracy:  0.1  out of 1.
#
# File number:  21
# File name:  ./TestRandomExamples100/Example15.txt
# Number of values tested:  42
# Accuracy:  0.4  out of 1.
#
# File number:  22
# File name:  ./TestRandomExamples100/Example39.txt
# Number of values tested:  65
# Accuracy:  0.8  out of 1.
#
# File number:  23
# File name:  ./TestRandomExamples100/Example16.txt
# Number of values tested:  59
# Accuracy:  0.03  out of 1.
#
# File number:  24
# File name:  ./TestRandomExamples100/Example40.txt
# Number of values tested:  76
# Accuracy:  0.78  out of 1.
#
# File number:  25
# File name:  ./TestRandomExamples100/Example17.txt
# Number of values tested:  19
# Accuracy:  1.0  out of 1.
#
# File number:  26
# File name:  ./TestRandomExamples100/Example41.txt
# Number of values tested:  93
# Accuracy:  0.94  out of 1.
#
# File number:  27
# File name:  ./TestRandomExamples100/Example18.txt
# Number of values tested:  146
# Accuracy:  0.9  out of 1.
#
# File number:  28
# File name:  ./TestRandomExamples100/Example42.txt
# Number of values tested:  87
# Accuracy:  0.75  out of 1.
#
# File number:  29
# File name:  ./TestRandomExamples100/Example19.txt
# Number of values tested:  203
# Accuracy:  0.8  out of 1.
#
# File number:  30
# File name:  ./TestRandomExamples100/Example43.txt
# Number of values tested:  83
# Accuracy:  0.77  out of 1.
#
# File number:  31
# File name:  ./TestRandomExamples100/Example20.txt
# Number of values tested:  150
# Accuracy:  0.93  out of 1.
#
# File number:  32
# File name:  ./TestRandomExamples100/Example44.txt
# Number of values tested:  187
# Accuracy:  0.82  out of 1.
#
# File number:  33
# File name:  ./TestRandomExamples100/Example21.txt
# Number of values tested:  49
# Accuracy:  0.24  out of 1.
#
# File number:  34
# File name:  ./TestRandomExamples100/Example45.txt
# Number of values tested:  144
# Accuracy:  0.49  out of 1.
#
# File number:  35
# File name:  ./TestRandomExamples100/Example22.txt
# Number of values tested:  111
# Accuracy:  0.84  out of 1.
#
# File number:  36
# File name:  ./TestRandomExamples100/Example46.txt
# Number of values tested:  172
# Accuracy:  0.62  out of 1.
#
# File number:  37
# File name:  ./TestRandomExamples100/Example23.txt
# Number of values tested:  77
# Accuracy:  0.08  out of 1.
#
# File number:  38
# File name:  ./TestRandomExamples100/Example47.txt
# Number of values tested:  74
# Accuracy:  0.66  out of 1.
#
# File number:  39
# File name:  ./TestRandomExamples100/Example24.txt
# Number of values tested:  18
# Accuracy:  1.0  out of 1.
#
# File number:  40
# File name:  ./TestRandomExamples100/Example48.txt
# Number of values tested:  42
# Accuracy:  0.64  out of 1.
#
# File number:  41
# File name:  ./TestRandomExamples100/Example25.txt
# Number of values tested:  12
# Accuracy:  0.58  out of 1.
#
# File number:  42
# File name:  ./TestRandomExamples100/Example49.txt
# Number of values tested:  42
# Accuracy:  0.4  out of 1.
#
# File number:  43
# File name:  ./TestRandomExamples100/Example26.txt
# Number of values tested:  40
# Accuracy:  0.78  out of 1.
#
# File number:  44
# File name:  ./TestRandomExamples100/Example50.txt
# Number of values tested:  97
# Accuracy:  0.48  out of 1.
#
# File number:  45
# File name:  ./TestRandomExamples100/Example27.txt
# Number of values tested:  52
# Accuracy:  0.06  out of 1.
#
# File number:  46
# File name:  ./TestRandomExamples100/Example51.txt
# Number of values tested:  32
# Accuracy:  0.16  out of 1.
#
# File number:  47
# File name:  ./TestRandomExamples100/Example28.txt
# Number of values tested:  260
# Accuracy:  0.32  out of 1.
#
# File number:  48
# File name:  ./TestRandomExamples100/Example52.txt
# Number of values tested:  38
# Accuracy:  0.89  out of 1.
#
# File number:  49
# File name:  ./TestRandomExamples100/Example29.txt
# Number of values tested:  102
# Accuracy:  0.95  out of 1.
#
# File number:  50
# File name:  ./TestRandomExamples100/Example53.txt
# Number of values tested:  84
# Accuracy:  0.61  out of 1.
#
# File number:  51
# File name:  ./TestRandomExamples100/Example30.txt
# Number of values tested:  53
# Accuracy:  0.81  out of 1.
#
# File number:  52
# File name:  ./TestRandomExamples100/Example54.txt
# Number of values tested:  76
# Accuracy:  0.66  out of 1.
#
# File number:  53
# File name:  ./TestRandomExamples100/Example31.txt
# Number of values tested:  94
# Accuracy:  0.73  out of 1.
#
# File number:  54
# File name:  ./TestRandomExamples100/Example55.txt
# Number of values tested:  90
# Accuracy:  0.0  out of 1.
#
# File number:  55
# File name:  ./TestRandomExamples100/Example32.txt
# Number of values tested:  93
# Accuracy:  0.65  out of 1.
#
# File number:  56
# File name:  ./TestRandomExamples100/Example56.txt
# Number of values tested:  56
# Accuracy:  0.95  out of 1.
#
# File number:  57
# File name:  ./TestRandomExamples100/Example57.txt
# Number of values tested:  124
# Accuracy:  0.6  out of 1.
#
# File number:  58
# File name:  ./TestRandomExamples100/Example58.txt
# Number of values tested:  93
# Accuracy:  0.94  out of 1.
#
# File number:  59
# File name:  ./TestRandomExamples100/Example59.txt
# Number of values tested:  7
# Accuracy:  0.86  out of 1.
#
# File number:  60
# File name:  ./TestRandomExamples100/Example60.txt
# Number of values tested:  42
# Accuracy:  0.88  out of 1.
#
# File number:  61
# File name:  ./TestRandomExamples100/Example61.txt
# Number of values tested:  74
# Accuracy:  0.69  out of 1.
#
# File number:  62
# File name:  ./TestRandomExamples100/Example62.txt
# Number of values tested:  114
# Accuracy:  0.84  out of 1.
#
# File number:  63
# File name:  ./TestRandomExamples100/Example63.txt
# Number of values tested:  79
# Accuracy:  0.63  out of 1.
#
# File number:  64
# File name:  ./TestRandomExamples100/Example64.txt
# Number of values tested:  33
# Accuracy:  0.15  out of 1.
#
# File number:  65
# File name:  ./TestRandomExamples100/Example65.txt
# Number of values tested:  32
# Accuracy:  0.22  out of 1.
#
# File number:  66
# File name:  ./TestRandomExamples100/Example66.txt
# Number of values tested:  112
# Accuracy:  0.9  out of 1.
#
# File number:  67
# File name:  ./TestRandomExamples100/Example67.txt
# Number of values tested:  159
# Accuracy:  0.48  out of 1.
#
# File number:  68
# File name:  ./TestRandomExamples100/Example68.txt
# Number of values tested:  42
# Accuracy:  0.9  out of 1.
#
# File number:  69
# File name:  ./TestRandomExamples100/Example69.txt
# Number of values tested:  203
# Accuracy:  0.89  out of 1.
#
# File number:  70
# File name:  ./TestRandomExamples100/Example70.txt
# Number of values tested:  247
# Accuracy:  0.06  out of 1.
#
# File number:  71
# File name:  ./TestRandomExamples100/Example71.txt
# Number of values tested:  123
# Accuracy:  0.63  out of 1.
#
# File number:  72
# File name:  ./TestRandomExamples100/Example72.txt
# Number of values tested:  82
# Accuracy:  0.82  out of 1.
#
# File number:  73
# File name:  ./TestRandomExamples100/Example73.txt
# Number of values tested:  69
# Accuracy:  0.13  out of 1.
#
# File number:  74
# File name:  ./TestRandomExamples100/Example74.txt
# 100%|██████████| 100/100 [00:00<00:00, 359.47it/s]
# Number of values tested:  98
# Accuracy:  0.79  out of 1.
#
# File number:  75
# File name:  ./TestRandomExamples100/Example75.txt
# Number of values tested:  26
# Accuracy:  0.42  out of 1.
#
# File number:  76
# File name:  ./TestRandomExamples100/Example76.txt
# Number of values tested:  79
# Accuracy:  0.92  out of 1.
#
# File number:  77
# File name:  ./TestRandomExamples100/Example77.txt
# Number of values tested:  83
# Accuracy:  0.0  out of 1.
#
# File number:  78
# File name:  ./TestRandomExamples100/Example78.txt
# Number of values tested:  36
# Accuracy:  0.17  out of 1.
#
# File number:  79
# File name:  ./TestRandomExamples100/Example79.txt
# Number of values tested:  32
# Accuracy:  0.22  out of 1.
#
# File number:  80
# File name:  ./TestRandomExamples100/Example80.txt
# Number of values tested:  159
# Accuracy:  0.61  out of 1.
#
# File number:  81
# File name:  ./TestRandomExamples100/Example81.txt
# Number of values tested:  116
# Accuracy:  0.92  out of 1.
#
# File number:  82
# File name:  ./TestRandomExamples100/Example82.txt
# Number of values tested:  70
# Accuracy:  0.84  out of 1.
#
# File number:  83
# File name:  ./TestRandomExamples100/Example83.txt
# Number of values tested:  144
# Accuracy:  0.56  out of 1.
#
# File number:  84
# File name:  ./TestRandomExamples100/Example84.txt
# Number of values tested:  66
# Accuracy:  0.35  out of 1.
#
# File number:  85
# File name:  ./TestRandomExamples100/Example85.txt
# Number of values tested:  190
# Accuracy:  0.34  out of 1.
#
# File number:  86
# File name:  ./TestRandomExamples100/Example86.txt
# Number of values tested:  82
# Accuracy:  0.89  out of 1.
#
# File number:  87
# File name:  ./TestRandomExamples100/Example87.txt
# Number of values tested:  103
# Accuracy:  0.79  out of 1.
#
# File number:  88
# File name:  ./TestRandomExamples100/Example88.txt
# Number of values tested:  46
# Accuracy:  0.33  out of 1.
#
# File number:  89
# File name:  ./TestRandomExamples100/Example89.txt
# Number of values tested:  102
# Accuracy:  0.53  out of 1.
#
# File number:  90
# File name:  ./TestRandomExamples100/Example90.txt
# Number of values tested:  149
# Accuracy:  0.58  out of 1.
#
# File number:  91
# File name:  ./TestRandomExamples100/Example91.txt
# Number of values tested:  192
# Accuracy:  0.48  out of 1.
#
# File number:  92
# File name:  ./TestRandomExamples100/Example92.txt
# Number of values tested:  56
# Accuracy:  0.82  out of 1.
#
# File number:  93
# File name:  ./TestRandomExamples100/Example93.txt
# Number of values tested:  304
# Accuracy:  0.86  out of 1.
#
# File number:  94
# File name:  ./TestRandomExamples100/Example94.txt
# Number of values tested:  39
# Accuracy:  0.0  out of 1.
#
# File number:  95
# File name:  ./TestRandomExamples100/Example95.txt
# Number of values tested:  101
# Accuracy:  0.92  out of 1.
#
# File number:  96
# File name:  ./TestRandomExamples100/Example96.txt
# Number of values tested:  118
# Accuracy:  0.78  out of 1.
#
# File number:  97
# File name:  ./TestRandomExamples100/Example97.txt
# Number of values tested:  0
# Accuracy:  0.0  out of 1.
#
# File number:  98
# File name:  ./TestRandomExamples100/Example98.txt
# Number of values tested:  183
# Accuracy:  0.9  out of 1.
#
# File number:  99
# File name:  ./TestRandomExamples100/Example99.txt
# Number of values tested:  74
# Accuracy:  0.76  out of 1.
#
# File number:  100
# File name:  ./TestRandomExamples100/Example100.txt
# Number of values tested:  40
# Accuracy:  0.07  out of 1.

# %% [markdown]
# ### Plot the results

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = result#np.random.normal(size = 1000)
plt.hist(x, bins=20)
plt.title('Balance accuracy of sample statements')
plt.xlabel('Balance accuracy')
plt.ylabel('Statements')

# %% [markdown]
# ### Read the xml and output using pandas

# %%
import xml.etree.cElementTree as et
import pandas as pd
 
def getvalueofnode(node):
    """ return node text or None """
    return node.text if node is not None else None
 
""" main """
path = './TestExamples/Example1.xml'
parsed_xml = et.parse(path)
dfcols = ['postdate', 'description','fee','payments','deposits','balance']
df_xml = pd.DataFrame(columns=dfcols)
child = parsed_xml.getroot().getchildren()[2].getchildren()
for node in child:
    postdate = node.find('postdate')
    description = node.find('description')
    fee = node.find('fee')
    payments = node.find('payments')
    deposits = node.find('deposits')
    balance = node.find('balance')

    df_xml = df_xml.append(
        pd.Series([getvalueofnode(postdate),
                   getvalueofnode(description),
                   getvalueofnode(fee),
                   getvalueofnode(payments),
                   getvalueofnode(deposits),
                   getvalueofnode(balance)], index=dfcols),
        ignore_index=True)

print df_xml
